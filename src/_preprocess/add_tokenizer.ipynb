# %% [markdown]
# # 토크나이저 학습용 데이터 전처리 (Program_0으로 일관화)

# %%
# 시퀀스 파일들 생성
import os
import json
import pretty_midi
from miditok import REMI, TokenizerConfig

# 시김새 토큰 매핑
SIKIM_TOKEN_MAP = {
    "남도 꺾는청": "<SIKIM_NamdoKkeokneuncheong>",
    "남도요성": "<SIKIM_NamdoYoseong>",
    "서도요성": "<SIKIM_SeodoYoseong>",
    "잔요성": "<SIKIM_JanyoSeong>",
    "전성": "<SIKIM_Jeonseong>",
    "퇴성": "<SIKIM_Toeseong>",
}

def get_sikim_ranges(json_path):
    with open(json_path, "r", encoding="utf-8") as f:
        data = json.load(f)
    result = []
    ann_info = data.get("annotation_data_info", {})
    for item in ann_info.get("single_tonguing_cd", []):
        if item.get("annotation_category") == "시김새":
            name = item.get("annotation_name")
            if name in SIKIM_TOKEN_MAP:
                start = float(item.get("start_time", 0))
                end = float(item.get("end_time", 0))
                result.append((SIKIM_TOKEN_MAP[name], start, end))
    return result

def insert_sikim_tokens(midi_path, json_path, tokenizer, tol=0.1):
    sikim_ranges = get_sikim_ranges(json_path)
    midi = pretty_midi.PrettyMIDI(midi_path)
    tokens = tokenizer.encode(midi_path).tokens
    notes = []
    for inst in midi.instruments:
        notes += inst.notes

    # 시김새 구간별로 노트에 삽입, 모든 Program은 Program_0으로 강제
    new_tokens = []
    note_idx = 0
    for tok in tokens:
        if tok.startswith("Program_"):
            new_tokens.append("Program_0")
        elif tok.startswith("Pitch_"):
            note_start = notes[note_idx].start if note_idx < len(notes) else None
            for sikim_tok, st, et in sikim_ranges:
                if note_start is not None and (st - tol) <= note_start <= (et + tol):
                    new_tokens.append(sikim_tok)
            note_idx += 1
            new_tokens.append(tok)
        else:
            new_tokens.append(tok)
    return new_tokens

if __name__ == "__main__":
    midi_dir = "/home/wjg980807/ai_music/dataset/ktm/aihub/midi"
    json_dir = "/home/wjg980807/ai_music/dataset/ktm/aihub/json"
    out_dir = "/home/wjg980807/ai_music/dataset/ktm/aihub/remi_with_sikim_program0"
    os.makedirs(out_dir, exist_ok=True)

    # Program_0만 허용, 시김새 토큰 추가된 config
    config = TokenizerConfig(
        use_programs=True,
        use_tempos=True,
        use_time_signatures=True,
        program_range=(0, 0),
        special_tokens=list(SIKIM_TOKEN_MAP.values())
    )
    remi_tokenizer = REMI(config)

    for fname in os.listdir(midi_dir):
        if fname.endswith(".mid"):
            stem = os.path.splitext(fname)[0]
            midi_path = os.path.join(midi_dir, fname)
            json_path = os.path.join(json_dir, f"{stem}.json")
            if not os.path.exists(json_path):
                continue
            tokens = insert_sikim_tokens(midi_path, json_path, remi_tokenizer, tol=0.1)
            with open(os.path.join(out_dir, f"{stem}.remi.txt"), "w", encoding="utf-8") as f:
                f.write(" ".join(tokens))
            print(f"✅ {fname} → 시김새+Program_0 REMI 시퀀스 생성")
# Out:
# ✅ AP_F07_06534.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08109.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS3_03090.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00014.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_03552.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02222.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_00269.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04670.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04688.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02024.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02554.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_FS1_00285.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_01517.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C04_07615.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03271.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C09_07721.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04127.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04648.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07249.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_05947.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_04086.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_FS1_02617.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07227.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07293.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05646.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02837.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04669.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02523.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_02887.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03489.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03995.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_02092.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03109.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_04865.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F01_05192.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_01466.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03680.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02639.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05552.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_CR2_01931.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02467.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01932.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS3_03095.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_02843.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05532.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03887.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03758.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02116.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00662.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01947.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01934.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08155.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02986.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03623.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C01_07121.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02510.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_02267.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_
mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02967.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C06_07687.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02023.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02688.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_00401.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C04_07612.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03790.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03782.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06570.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02798.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03975.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E02_00866.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_00956.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03491.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AM_E05_05634.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03120.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04745.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00622.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_04042.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_04079.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AM_E01_02255.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_00961.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02012.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05480.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01769.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04143.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_05114.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02733.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06456.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_00332.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_CR2_00119.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_01896.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02080.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F01_05184.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C09_07709.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03642.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01325.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_00099.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08156.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03257.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_CR2_00136.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_01753.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_00141.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_01972.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05441.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_04094.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_01514.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05604.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02718.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_FS3_03075.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02644.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06543.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07261.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04727.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_00832.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_06812.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06664.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_FS2_03347.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C07_07622.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04752.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03006.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02688.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02936.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03203.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00161.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00165.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_00289.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07506.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BM_FS1_02497.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04221.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C04_07596.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_00070.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05513.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_00139.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02923.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_00905.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00762.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_00148.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03039.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_02146.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03777.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06314.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02039.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_02122.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02554.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04236.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08138.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04586.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03989.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_04030.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02838.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04666.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_02535.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E02_04859.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03193.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02434.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02522.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_06915.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00703.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C09_02191.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06778.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03624.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02795.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_00184.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05549.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_00584.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_05397.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03520.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS3_02994.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02012.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C08_07649.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C06_07675.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03971.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AM_E01_03254.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_02844.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04257.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05610.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C09_07723.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_00998.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C01_07118.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02744.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_06900.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02007.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05507.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS3_03034.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03617.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_04159.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR1_02720.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_05394.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_02834.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02845.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E05_05616.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00861.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06728.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_04612.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F01_05252.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08161.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06346.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03367.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03878.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03242.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_08121.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00476.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E04_02054.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F06_00469.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03588.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03895.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F01_06046.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_02513.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03591.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS3_03058.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F07_06503.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_02312.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E02_04881.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07521.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02873.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03665.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F02_07442.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_F01_05969.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02284.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS2_01511.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AM_E01_04032.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02497.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00508.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_FS1_00198.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ BP_CR2_00692.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_C01_07117.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_02867.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_05143.mid → 시김새+Program_0 REMI 시퀀스 생성
# ✅ AP_E01_03090.mid → 시김새+Program_0 REMI 시퀀스 생성

# %% [markdown]
# # 토크나이저 학습

# %%
# midi  변환 (시김새 추가)
import os
import mido
import json

SIKIM_ENG_MAP = {
    "남도 꺾는청": "NamdoKkeokneuncheong",
    "남도요성": "NamdoYoseong",
    "서도요성": "SeodoYoseong",
    "잔요성": "JanyoSeong",
    "전성": "Jeonseong",
    "퇴성": "Toeseong",
}

def add_sikimsa_text_events(midi_path, json_path, output_path):
    try:
        with open(json_path, "r", encoding="utf-8") as f:
            data = json.load(f)
        sikim_ranges = []
        for item in data.get("annotation_data_info", {}).get("single_tonguing_cd", []):
            if item.get("annotation_category") == "시김새":
                name = item.get("annotation_name")
                name_eng = SIKIM_ENG_MAP.get(name, name)
                start = float(item.get("start_time", 0))
                sikim_ranges.append((name_eng, start))

        mid = mido.MidiFile(midi_path)
        track = mid.tracks[0]
        tempo = 500000
        for msg in track:
            if msg.type == 'set_tempo':
                tempo = msg.tempo
                break

        def sec2tick(sec):
            return int(mido.second2tick(sec, mid.ticks_per_beat, tempo))

        text_msgs = []
        for name, start_sec in sikim_ranges:
            tick = sec2tick(start_sec)
            text_msgs.append((tick, mido.MetaMessage('text', text=f"SIKIM:{name}", time=0)))

        new_msgs = []
        abs_tick = 0
        text_idx = 0
        text_msgs.sort()

        for msg in track:
            abs_tick += msg.time
            while text_idx < len(text_msgs) and abs_tick >= text_msgs[text_idx][0]:
                new_msgs.append(mido.MetaMessage('text', text=text_msgs[text_idx][1].text, time=0))
                text_idx += 1
            new_msgs.append(msg)
        for i in range(text_idx, len(text_msgs)):
            new_msgs.append(mido.MetaMessage('text', text=text_msgs[i][1].text, time=0))

        mid.tracks[0] = mido.MidiTrack(new_msgs)
        mid.save(output_path)
        print(f"✅ {output_path} 변환 완료")
    except Exception as e:
        print(f"[ERROR] {midi_path}: {e}")

if __name__ == "__main__":
    midi_dir = "/home/wjg980807/ai_music/dataset/ktm/aihub
mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_04221.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C04_07596.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_00070.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_05513.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_00139.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02923.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS2_00905.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00762.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_00148.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03039.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_02146.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03777.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F07_06314.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E04_02039.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_02122.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR1_02554.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_04236.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_08138.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_04586.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03989.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_04030.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02838.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_04666.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS1_02535.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E02_04859.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03193.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02434.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR1_02522.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_06915.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00703.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C09_02191.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F07_06778.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03624.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02795.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS1_00184.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_05549.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_00584.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_05397.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03520.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS3_02994.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR1_02012.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C08_07649.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C06_07675.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03971.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AM_E01_03254.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS2_02844.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_04257.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_05610.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C09_07723.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_00998.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C01_07118.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR1_02744.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_06900.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E04_02007.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_05507.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS3_03034.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03617.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_04159.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR1_02720.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_05394.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS2_02834.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02845.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E05_05616.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00861.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F07_06728.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_04612.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F01_05252.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_08161.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F07_06346.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03367.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03878.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03242.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_08121.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00476.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E04_02054.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F06_00469.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03588.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03895.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F01_06046.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS1_02513.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03591.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS3_03058.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F07_06503.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_02312.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E02_04881.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_07521.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02873.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03665.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F02_07442.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_F01_05969.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02284.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS2_01511.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AM_E01_04032.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02497.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00508.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_FS1_00198.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/BP_CR2_00692.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_C01_07117.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_02867.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_05143.mid 변환 완료
# ✅ /home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae/AP_E01_03090.mid 변환 완료

# %%
from miditok import REMI, TokenizerConfig

# 구성 정의
config = TokenizerConfig(
    use_programs=True,
    use_tempos=True,
    use_time_signatures=True,
    program_range=(0, 0),
    special_tokens=[
        "<SIKIM_NamdoKkeokneuncheong>", "<SIKIM_NamdoYoseong>",
        "<SIKIM_SeodoYoseong>", "<SIKIM_JanyoSeong>",
        "<SIKIM_Jeonseong>", "<SIKIM_Toeseong>"
    ]
)
tokenizer = REMI(config)

# %%
from miditok import REMI, TokenizerConfig
import glob

# 1. config 생성
config = TokenizerConfig(
    use_programs=True,
    use_tempos=True,
    use_time_signatures=True,
    program_range=(0, 0),
    special_tokens=[
        "<SIKIM_NamdoKkeokneuncheong>", "<SIKIM_NamdoYoseong>",
        "<SIKIM_SeodoYoseong>", "<SIKIM_JanyoSeong>",
        "<SIKIM_Jeonseong>", "<SIKIM_Toeseong>"
    ]
)
tokenizer = REMI(config)

# 2. vocab 직접 구성
txt_files = glob.glob("/home/wjg980807/ai_music/dataset/ktm/aihub/remi_with_sikim_program0/*.remi.txt")
all_tokens = set()
for path in txt_files:
    with open(path, "r", encoding="utf-8") as f:
        all_tokens.update(f.read().split())

vocab = {tok: i for i, tok in enumerate(sorted(all_tokens))}
tokenizer._vocab = vocab
tokenizer._vocab_inv = {i: tok for tok, i in vocab.items()}

# 3. 저장
tokenizer.save_pretrained("/home/wjg980807/ai_music/dataset/ktm/aihub/tokenizer_sikim_trained")

# %%
import json

save_path = "/home/wjg980807/ai_music/dataset/ktm/aihub/tokenizer_sikim_trained/vocab.json"

# 이미 존재하는 tokenizer._vocab 사용
with open(save_path, "w", encoding="utf-8") as f:
    json.dump(tokenizer._vocab, f, ensure_ascii=False, indent=4)

print(f"✅ vocab.json 저장 완료 → {save_path}")
# Out:
# ✅ vocab.json 저장 완료 → /home/wjg980807/ai_music/dataset/ktm/aihub/tokenizer_sikim_trained/vocab.json

# %% [markdown]
# # 테스트

# %%
# 1. 시퀀스 불러오기
with open("/home/wjg980807/ai_music/dataset/ktm/aihub/remi_with_sikim_program0/BP_FS3_03102.remi.txt", encoding="utf-8") as f:
    tokens = f.read().split()

# 2. 시김새 토큰만 추출
print("🎵 Detected SIKIM tokens from .remi.txt:")
for t in tokens:
    if "SIKIM" in t:
        print("✅", t)
# Out:
# 🎵 Detected SIKIM tokens from .remi.txt:
# ✅ <SIKIM_JanyoSeong>
# ✅ <SIKIM_JanyoSeong>
# ✅ <SIKIM_NamdoKkeokneuncheong>
# ✅ <SIKIM_NamdoKkeokneuncheong>
# ✅ <SIKIM_NamdoYoseong>
# ✅ <SIKIM_JanyoSeong>
# ✅ <SIKIM_JanyoSeong>
# ✅ <SIKIM_NamdoKkeokneuncheong>
# ✅ <SIKIM_NamdoKkeokneuncheong>

# %%
import os
import mido

midi_dir = "/home/wjg980807/ai_music/dataset/ktm/aihub/midi_with_sikimsae"

for fname in sorted(os.listdir(midi_dir)):
    if not fname.endswith(".mid"):
        continue

    midi_path = os.path.join(midi_dir, fname)
    midi = mido.MidiFile(midi_path)

    sikim_events = []
    for track in midi.tracks:
        for msg in track:
            if msg.is_meta and msg.type == 'text' and msg.text.startswith("SIKIM:"):
                sikim_events.append(msg.text)

    if sikim_events:
        print(f"🎯 {fname} - 시김새 이벤트 {len(sikim_events)}개")
        for evt in sikim_events:
            print("   →", evt)
    else:
        print(f"⚠️ {fname} - 시김새 이벤트 없음")
# Out:
# ⚠️ AM_C01_08594.mid - 시김새 이벤트 없음
# 🎯 AM_C03_07798.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# ⚠️ AM_C04_07566.mid - 시김새 이벤트 없음
# ⚠️ AM_C04_07589.mid - 시김새 이벤트 없음
# ⚠️ AM_C04_07605.mid - 시김새 이벤트 없음
# 🎯 AM_C06_07668.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# ⚠️ AM_C07_07618.mid - 시김새 이벤트 없음
# ⚠️ AM_C08_07643.mid - 시김새 이벤트 없음
# 🎯 AM_C09_02208.mid - 시김새 이벤트 9개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_C09_07698.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02255.mid - 시김새 이벤트 9개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02406.mid - 시김새 이벤트 23개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02425.mid - 시김새 이벤트 19개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_02435.mid - 시김새 이벤트 1개
#    → SIKIM:Jeonseong
# 🎯 AM_E01_02473.mid - 시김새 이벤트 8개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_02490.mid - 시김새 이벤트 5개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02524.mid - 시김새 이벤트 27개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02537.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Jeonseong
#    → SIKIM:Jeonseong
#    → SIKIM:Jeonseong
#    → SIKIM:Jeonseong
#    → SIKIM:Toeseong
# 🎯 AM_E01_02699.mid - 시김새 이벤트 11개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02784.mid - 시김새 이벤트 18개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02832.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02883.mid - 시김새 이벤트 18개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02943.mid - 시김새 이벤트 12개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_02944.mid - 시김새 이벤트 15개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03026.mid - 시김새 이벤트 16개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03059.mid - 시김새 이벤트 28개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03117.mid - 시김새 이벤트 27개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03140.mid - 시김새 이벤트 11개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03184.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03254.mid - 시김새 이벤트 18개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03301.mid - 시김새 이벤트 21개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_03331.mid - 시김새 이벤트 19개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_03481.mid - 시김새 이벤트 27개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03575.mid - 시김새 이벤트 9개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_03728.mid - 시김새 이벤트 11개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03769.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Jeonseong
# 🎯 AM_E01_03815.mid - 시김새 이벤트 25개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_03852.mid - 시김새 이벤트 18개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Jeonseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_04032.mid - 시김새 이벤트 6개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_04071.mid - 시김새 이벤트 9개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_04089.mid - 시김새 이벤트 17개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_06896.mid - 시김새 이벤트 16개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_06928.mid - 시김새 이벤트 10개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_06955.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_06968.mid - 시김새 이벤트 10개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_06977.mid - 시김새 이벤트 11개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_07004.mid - 시김새 이벤트 13개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 AM_E01_07024.mid - 시김새 이벤트 11개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_07040.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_08642.mid - 시김새 이벤트 14개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_E01_08644.mid - 시김새 이벤트 13개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 AM_
mid - 시김새 이벤트 없음
# 🎯 BP_FS2_03554.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03555.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03556.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# ⚠️ BP_FS2_03557.mid - 시김새 이벤트 없음
# 🎯 BP_FS2_03558.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03559.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# ⚠️ BP_FS2_03560.mid - 시김새 이벤트 없음
# 🎯 BP_FS2_03561.mid - 시김새 이벤트 1개
#    → SIKIM:Toeseong
# 🎯 BP_FS2_03562.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03563.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03564.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03565.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03566.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03567.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03568.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# ⚠️ BP_FS2_03569.mid - 시김새 이벤트 없음
# 🎯 BP_FS2_03570.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03571.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03572.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03573.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03574.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03575.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03576.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03577.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# ⚠️ BP_FS2_03578.mid - 시김새 이벤트 없음
# 🎯 BP_FS2_03595.mid - 시김새 이벤트 6개
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoKkeokneuncheong
# 🎯 BP_FS2_03600.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS2_03601.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02988.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02989.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02990.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02991.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02992.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02993.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02994.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02995.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02996.mid - 시김새 이벤트 6개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02997.mid - 시김새 이벤트 5개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_02998.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_02999.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03000.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03001.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03002.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03003.mid - 시김새 이벤트 4개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03005.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03006.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03007.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03009.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03010.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03011.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03021.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03022.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03023.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03024.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03026.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03027.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03028.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03029.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03030.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03031.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03032.mid - 시김새 이벤트 1개
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03033.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03034.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoKkeokneuncheong
# 🎯 BP_FS3_03035.mid - 시김새 이벤트 3개
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03036.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03037.mid - 시김새 이벤트 1개
#    → SIKIM:NamdoKkeokneuncheong
# 🎯 BP_FS3_03038.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03039.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03040.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03041.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03042.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03044.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03045.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03046.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03047.mid - 시김새 이벤트 8개
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03049.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03050.mid - 시김새 이벤트 5개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03051.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03052.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03053.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03054.mid - 시김새 이벤트 9개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03055.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03056.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03057.mid - 시김새 이벤트 4개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03058.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03059.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03060.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03061.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03062.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03063.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03064.mid - 시김새 이벤트 6개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03065.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03066.mid - 시김새 이벤트 1개
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03067.mid - 시김새 이벤트 12개
#    → SIKIM:Toeseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:Toeseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03068.mid - 시김새 이벤트 9개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03069.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03070.mid - 시김새 이벤트 2개
#    → SIKIM:Toeseong
#    → SIKIM:NamdoKkeokneuncheong
# 🎯 BP_FS3_03071.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03072.mid - 시김새 이벤트 1개
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03073.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03074.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03076.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03077.mid - 시김새 이벤트 3개
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03082.mid - 시김새 이벤트 15개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03083.mid - 시김새 이벤트 2개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03084.mid - 시김새 이벤트 4개
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03085.mid - 시김새 이벤트 1개
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03086.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03089.mid - 시김새 이벤트 4개
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03090.mid - 시김새 이벤트 10개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:Toeseong
# 🎯 BP_FS3_03091.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03092.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03093.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03094.mid - 시김새 이벤트 3개
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03095.mid - 시김새 이벤트 8개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03096.mid - 시김새 이벤트 1개
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03097.mid - 시김새 이벤트 7개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03098.mid - 시김새 이벤트 5개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03099.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
# 🎯 BP_FS3_03100.mid - 시김새 이벤트 5개
#    → SIKIM:NamdoYoseong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
#    → SIKIM:JanyoSeong
# 🎯 BP_FS3_03102.mid - 시김새 이벤트 6개
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoYoseong
#    → SIKIM:JanyoSeong
#    → SIKIM:NamdoKkeokneuncheong
#    → SIKIM:NamdoYoseong

# %% [markdown]
# # 번외

# %%
from miditok import REMI, TokenizerConfig
import glob

config = TokenizerConfig(
    use_programs=True,
    use_tempos=True,
    use_time_signatures=True,
    program_range=(0, 0),
    special_tokens=[
        "<SIKIM_남도꺾는청>", "<SIKIM_남도요성>", "<SIKIM_서도요성>",
        "<SIKIM_잔요성>", "<SIKIM_전성>", "<SIKIM_퇴성>"
    ]
)
tokenizer = REMI(config)

# 🚩 반드시! REMI 시퀀스(.remi.txt) 리스트로 학습해야 함
txt_files = glob.glob("/home/wjg980807/ai_music/dataset/ktm/aihub/remi_with_sikim_program0/*.remi.txt")
tokenizer.train(2048, iterator=txt_files)
tokenizer.save("/home/wjg980807/ai_music/dataset/ktm/aihub/tokenizer_sikim")
